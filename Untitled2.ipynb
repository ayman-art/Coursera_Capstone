# %% [markdown]
# CHINESE Places in a particular place in America(New York)

# %% [markdown]
# 1.IMPORTING THE LIBRARIES

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values


from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.3
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1g-h516909a_0 --> 1.1.1g-h516909a_1
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# 2.DEFINING THE PERSONAL DATA & SOME OPTIONS

# %%
CLIENT_ID = 'FOERNFLVSSIN2X45T0OP3GXZAKZSM0VCWVGTTIWG23WG53JZ' # your Foursquare ID
CLIENT_SECRET = 'IHLUHIXCLZEIJUGZOTZRLESDD0TI1TXIJQ20T2TYVMK1QL2V' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FOERNFLVSSIN2X45T0OP3GXZAKZSM0VCWVGTTIWG23WG53JZ
# CLIENT_SECRET:IHLUHIXCLZEIJUGZOTZRLESDD0TI1TXIJQ20T2TYVMK1QL2V

# %%
address = ' New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7127281 -74.0060152

# %%
search_query = 'Chinese'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Chinese .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FOERNFLVSSIN2X45T0OP3GXZAKZSM0VCWVGTTIWG23WG53JZ&client_secret=IHLUHIXCLZEIJUGZOTZRLESDD0TI1TXIJQ20T2TYVMK1QL2V&ll=40.7127281,-74.0060152&v=20180604&query=Chinese&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f3aaf289ed85e68a2dd4365'},
#  'response': {'venues': [{'id': '4d9f5e228e8f224bcd8ca256',
#     'name': 'Chinese Wah Lai Funeral Home',
#     'location': {'address': '22 Mulberry St',
#      'lat': 40.71417,
#      'lng': -73.99941700000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.71417,
#        'lng': -73.99941700000001},
#       {'label': 'entrance', 'lat': 40.714179, 'lng': -73.999499}],
#      'distance': 579,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['22 Mulberry St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4f4534884b9074f6e4fb0174',
#       'name': 'Funeral Home',
#       'pluralName': 'Funeral Homes',
#       'shortName': 'Funeral Home',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/funeralhome_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597681615',
#     'hasPerk': False},
#    {'id': '51be2d6f498e7a73436bd59a',
#     'name': 'Chinese Qigong Massage',
#     'location': {'address': '68 White St',
#      'crossStreet': 'Broadway And Church',
#      'lat': 40.718223571777344,
#      'lng': -74.00328063964844,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.718223571777344,
#        'lng': -74.00328063964844}],
#      'distance': 653,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['68 White St (Broadway And Church)',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#       'name': 'Massage Studio',
#       'pluralName': 'Massage Studios',
#       'shortName': 'Massage Studio',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597681615',
#     'hasPerk': False},
#    {'id': '581299bb38fa2e54303f6891',
#     'name': 'Taste Chinese Restaurant',
#     'location': {'address': '178 Church St',
#      'lat': 40.7156902,
#      'lng': -74.0076053,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7156902,
#        'lng': -74.0076053}],
#      'distance': 355,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['178 Church St',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '322507',
#      'url': 'https://www.seamless.com/menu/taste-chinese-restaurant-178-church-st-new-york/322507?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=322507',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1597681615',
#     'hasPerk': False},
#    {'id': '4f320f6d19833175d60c8d97',
#     'name': 'Downtown Chinese Restaurant',
#     'location': {'address': '135 John St',
#      'lat': 40.70713424682617,
#      'lng': -74.00494384765625,
#      'labeledLatLngs': [{'label': 'entrance',
#        'lat': 40.707098,
#        'lng': -74.005032},
#       {'label': 'display',
#        'lat': 40.70713424682617,
#        'lng': -74.00494384765625}],
#      'distance': 629,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['135 John St',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597681615',
#     'hasPerk': False},
#    {'id': '4a982c7af964a520cc2a20e3',
#     'name': 'China 59',
#     'location': {'address': '59 Nassau St',
#      'crossStreet': 'btwn Maiden Lane & John St',
#      'lat': 40.70917839380905,
#      'lng': -74.00895826776383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.70917839380905,
#        'lng': -74.00895826776383}],
#      'distance': 466,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['59 Nassau St (btwn Maiden Lane & John St)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597681615',
#     'hasPerk': False},
#    {'id': '4b88199af964a520e6df31e3',
#     'name': 'Win Won Restaurant',
#     'location': {'address': '10 Liberty Pl',
#      'crossStreet': 'Maiden Lane',
#      'lat': 40.709193,
#      'lng': -74.009344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.709193,
#        'lng': -74.009344},
#       {'label': 'entrance', 'lat': 40.709177, 'lng': -74.009278}],
#      'distance': 483,
#      'postalCode': '10038',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Liberty Pl (Maiden Lane)',
#       'New York, NY 10038',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1597681615',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                          name  \
# 0  4d9f5e228e8f224bcd8ca256  Chinese Wah Lai Funeral Home
# 1  51be2d6f498e7a73436bd59a        Chinese Qigong Massage
# 2  581299bb38fa2e54303f6891      Taste Chinese Restaurant
# 3  4f320f6d19833175d60c8d97   Downtown Chinese Restaurant
# 4  4a982c7af964a520cc2a20e3                      China 59
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4f4534884b9074f6e4fb0174', 'name': 'F...  v-1597681615    False
# 1  [{'id': '52f2ab2ebcbc57f1066b8b3c', 'name': 'M...  v-1597681615    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1597681615    False
# 3  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...  v-1597681615    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1597681615    False
#
#   location.address  location.lat  location.lng  \
# 0   22 Mulberry St     40.714170    -73.999417
# 1      68 White St     40.718224    -74.003281
# 2    178 Church St     40.715690    -74.007605
# 3      135 John St     40.707134    -74.004944
# 4     59 Nassau St     40.709178    -74.008958
#
#                              location.labeledLatLngs  location.distance  ...  \
# 0  [{'label': 'display', 'lat': 40.71417, 'lng': ...                579  ...
# 1  [{'label': 'display', 'lat': 40.71822357177734...                653  ...
# 2  [{'label': 'display', 'lat': 40.7156902, 'lng'...                355  ...
# 3  [{'label': 'entrance', 'lat': 40.707098, 'lng'...                629  ...
# 4  [{'label': 'display', 'lat': 40.70917839380905...                466  ...
#
#   location.state location.country  \
# 0             NY    United States
# 1             NY    United States
# 2             NY    United States
# 3             NY    United States
# 4             NY    United States
#
#                            location.formattedAddress  \
# 0  [22 Mulberry St, New York, NY 10013, United St...
# 1  [68 White St (Broadway And Church), New York, ...
# 2  [178 Church St, New York, NY 10013, United Sta...
# 3   [135 John St, New York, NY 10038, United States]
# 4  [59 Nassau St (btwn Maiden Lane & John St), Ne...
#
#          location.crossStreet delivery.id  \
# 0                         NaN         NaN
# 1         Broadway And Church         NaN
# 2                         NaN      322507
# 3                         NaN         NaN
# 4  btwn Maiden Lane & John St         NaN
#
#                                         delivery.url delivery.provider.name  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2  https://www.seamless.com/menu/taste-chinese-re...               seamless
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#                 delivery.provider.icon.name
# 0                                       NaN
# 1                                       NaN
# 2  /delivery_provider_seamless_20180129.png
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 23 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                            name          categories         address  \
# 0  Chinese Wah Lai Funeral Home        Funeral Home  22 Mulberry St
# 1        Chinese Qigong Massage      Massage Studio     68 White St
# 2      Taste Chinese Restaurant  Chinese Restaurant   178 Church St
# 3   Downtown Chinese Restaurant                Food     135 John St
# 4                      China 59  Chinese Restaurant    59 Nassau St
# 5            Win Won Restaurant  Chinese Restaurant   10 Liberty Pl
#
#          lat        lng                                     labeledLatLngs  \
# 0  40.714170 -73.999417  [{'label': 'display', 'lat': 40.71417, 'lng': ...
# 1  40.718224 -74.003281  [{'label': 'display', 'lat': 40.71822357177734...
# 2  40.715690 -74.007605  [{'label': 'display', 'lat': 40.7156902, 'lng'...
# 3  40.707134 -74.004944  [{'label': 'entrance', 'lat': 40.707098, 'lng'...
# 4  40.709178 -74.008958  [{'label': 'display', 'lat': 40.70917839380905...
# 5  40.709193 -74.009344  [{'label': 'display', 'lat': 40.709193, 'lng':...
#
#    distance postalCode  cc      city state        country  \
# 0       579      10013  US  New York    NY  United States
# 1       653      10013  US  New York    NY  United States
# 2       355      10013  US  New York    NY  United States
# 3       629      10038  US  New York    NY  United States
# 4       466      10038  US  New York    NY  United States
# 5       483      10038  US  New York    NY  United States
#
#                                     formattedAddress  \
# 0  [22 Mulberry St, New York, NY 10013, United St...
# 1  [68 White St (Broadway And Church), New York, ...
# 2  [178 Church St, New York, NY 10013, United Sta...
# 3   [135 John St, New York, NY 10038, United States]
# 4  [59 Nassau St (btwn Maiden Lane & John St), Ne...
# 5  [10 Liberty Pl (Maiden Lane), New York, NY 100...
#
#                   crossStreet                        id
# 0                         NaN  4d9f5e228e8f224bcd8ca256
# 1         Broadway And Church  51be2d6f498e7a73436bd59a
# 2                         NaN  581299bb38fa2e54303f6891
# 3                         NaN  4f320f6d19833175d60c8d97
# 4  btwn Maiden Lane & John St  4a982c7af964a520cc2a20e3
# 5                 Maiden Lane  4b88199af964a520e6df31e3

# %% [markdown]
# the number of chinese places

# %%
dataframe_filtered.shape
# Out:
# (6, 15)

# %%
dataframe_filtered.name
# Out:
# 0    Chinese Wah Lai Funeral Home
# 1          Chinese Qigong Massage
# 2        Taste Chinese Restaurant
# 3     Downtown Chinese Restaurant
# 4                        China 59
# 5              Win Won Restaurant
# Name: name, dtype: object

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.
